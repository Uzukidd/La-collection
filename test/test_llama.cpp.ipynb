# %%
from llama_cpp import Llama, llama_chat_format

llm = Llama(
      model_path="/mnt/sda/modelzoo/llms/guff/DeepSeek-R1-Distill-Qwen-32B-f16-q8_0.gguf",
      verbose=True,
      n_gpu_layers=-1, # Uncomment to use GPU acceleration
      # seed=1337, # Uncomment to set a specific seed
      # n_ctx=2048, # Uncomment to increase the context window
)
# Out:
# ggml_cuda_init: GGML_CUDA_FORCE_MMQ:    no
# ggml_cuda_init: GGML_CUDA_FORCE_CUBLAS: no
# ggml_cuda_init: found 4 CUDA devices:
#   Device 0: NVIDIA GeForce RTX 4090, compute capability 8.9, VMM: yes
#   Device 1: NVIDIA GeForce RTX 4090, compute capability 8.9, VMM: yes
#   Device 2: NVIDIA GeForce RTX 4090, compute capability 8.9, VMM: yes
#   Device 3: NVIDIA GeForce RTX 4090, compute capability 8.9, VMM: yes
# llama_model_load_from_file_impl: using device CUDA0 (NVIDIA GeForce RTX 4090) - 23808 MiB free
# llama_model_load_from_file_impl: using device CUDA1 (NVIDIA GeForce RTX 4090) - 23808 MiB free
# llama_model_load_from_file_impl: using device CUDA2 (NVIDIA GeForce RTX 4090) - 23808 MiB free
# llama_model_load_from_file_impl: using device CUDA3 (NVIDIA GeForce RTX 4090) - 23808 MiB free
# llama_model_loader: loaded meta data with 30 key-value pairs and 771 tensors from /mnt/sda/modelzoo/llms/guff/DeepSeek-R1-Distill-Qwen-32B-f16-q8_0.gguf (version GGUF V3 (latest))
# ...

# %%
response = llm.create_chat_completion(messages=[
        {"role": "user", "content": "目前的美国总统是谁"}
    ], stream=True)
think_token = "</think>"
for token in response:
    content = token['choices'][0]['delta']
    if 'content' in content:
        if "think" in content['content']:
            print(content)
# Out:
# Llama.generate: 8 prefix-match hit, remaining 1 prompt tokens to eval
# {'content': '</think>'}
# llama_perf_context_print:        load time =     448.93 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /     1 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =   15577.25 ms /   367 runs   (   42.44 ms per token,    23.56 tokens per second)
# llama_perf_context_print:       total time =   16114.94 ms /   368 tokens

# %%
output = llm(
      "Who are you? A:", # Prompt
      max_tokens=None,
      stop=["Q:", "\n"],
      echo=False
)
print(output["choices"][0])
# Out:
# Llama.generate: 5 prefix-match hit, remaining 2 prompt tokens to eval
# llama_perf_context_print:        load time =     383.31 ms
# llama_perf_context_print: prompt eval time =      52.77 ms /     2 tokens (   26.39 ms per token,    37.90 tokens per second)
# llama_perf_context_print:        eval time =    2478.03 ms /    58 runs   (   42.72 ms per token,    23.41 tokens per second)
# llama_perf_context_print:       total time =    2632.95 ms /    60 tokens
# {'text': " I'm DeepSeek-R1, an AI assistant created exclusively by the Chinese Company DeepSeek. I'll do my best to help you.  B: I'm DeepSeek-R1, an AI assistant created exclusively by the Chinese Company DeepSeek. I'll do my best to help you.", 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}
